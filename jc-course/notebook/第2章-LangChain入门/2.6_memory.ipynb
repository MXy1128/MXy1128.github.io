# %%
# 加载环境变量
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 1.没有记忆时

# %%
from langchain.agents import create_agent

agent = create_agent(model = "deepseek-chat")

# %%
from langchain.messages import HumanMessage

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]}
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='1bef9751-1a3d-4c1b-983a-f647659abbd7'), AIMessage(content='你好，虎哥！👋 很高兴认识你～ 猫猫确实超可爱的，蓬松的毛发、软软的肉垫，还有那些古灵精怪的小表情，谁能拒绝呢？🐱✨ 你家里有养猫吗？还是云吸猫选手呀？😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 15, 'total_tokens': 77, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '08844c03-9c75-4665-bfaf-aa48b9dcbf34', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2171-e788-7461-b107-88fe8c640925-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 62, 'total_tokens': 77, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢什么动物?")]}
)

print(response)
# Out:
# {'messages': [HumanMessage(content='我最喜欢什么动物?', additional_kwargs={}, response_metadata={}, id='23169698-b772-4b37-ac8e-7e6d147712a0'), AIMessage(content='这个问题只有你自己才能准确回答哦！不过，我可以帮你一起猜猜看——你最喜欢的是聪明忠诚的**狗**、高冷优雅的**猫**，还是自由翱翔的**鸟**？或者你喜欢某种特别的动物，比如**熊猫**、**海豚**，甚至是奇特的**树懒**？  \n\n不妨透露一点线索吧？比如：它生活在哪里？有什么让你着迷的特点？或者你的性格和它有什么相似之处？😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 9, 'total_tokens': 107, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '2b4a4d4f-8e61-4b5b-a85a-61976655199c', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2171-fbdf-7ec3-ac24-c5488bd70bf2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 98, 'total_tokens': 107, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 2.添加记忆
#
# 添加会话记忆（短期记忆）分为三步：
# - 导入并初始化Checkpointer
# - 创建Agent，指定Checkpointer
# - 调用Agent，指定thread_id

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver


agent = create_agent(
    "deepseek-chat",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

# 设定thread_id，作为会话标识
config = {"configurable": {"thread_id": "thread_1"}}

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='4b00627b-fc61-4cc1-bd51-b458a4717147'), AIMessage(content='你好虎哥！🐱 猫猫真的超可爱，软乎乎的肉垫、好奇的眼神，还有各种傲娇的小表情～你家里养猫了吗？还是经常云吸猫呀？😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 15, 'total_tokens': 58, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '2353d68d-d541-44b9-af0d-916f0c9e5b1f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2177-d1b2-7423-8c31-580bc47a3ebe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 43, 'total_tokens': 58, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢的动物是什么？")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='4b00627b-fc61-4cc1-bd51-b458a4717147'), AIMessage(content='你好虎哥！🐱 猫猫真的超可爱，软乎乎的肉垫、好奇的眼神，还有各种傲娇的小表情～你家里养猫了吗？还是经常云吸猫呀？😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 15, 'total_tokens': 58, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '2353d68d-d541-44b9-af0d-916f0c9e5b1f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2177-d1b2-7423-8c31-580bc47a3ebe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 43, 'total_tokens': 58, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我最喜欢的动物是什么？', additional_kwargs={}, response_metadata={}, id='6c996362-0698-4d85-ab24-d9cf4dd92396'), AIMessage(content='哈哈，虎哥你刚刚才说过最喜欢猫猫呀～所以答案当然是 **猫猫** 啦！🐱✨  \n（如果需要换个答案…那也可能是你头像里的猫？或者你灵魂里其实住着一只猫？😉）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 67, 'total_tokens': 119, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 67}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'f2f44247-899e-4e70-8152-b5e65244247d', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2178-001f-77b2-8773-71a9dd1c7917-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 67, 'output_tokens': 52, 'total_tokens': 119, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 3.Memory持久化存储
#
# 这里我们选择使用Sqlite作为存储方案，首先需要按照langgraph-checkpoint-sqlite依赖：
# ```
# uv add langgraph-checkpoint-sqlite
# ```
# 接着，按照以下步骤使用：
# - 导入依赖
# - 初始化checkpointer
# - 自动建表
# - 创建Agent，指定checkpointer

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

# 连接sqlite
connection = sqlite3.connect("resources/checkpoint.db", check_same_thread=False)
# 初始化checkpointer
checkpointer = SqliteSaver(connection)
# 自动建表
checkpointer.setup()

# 创建agent
agent = create_agent(
    "deepseek-chat",
    checkpointer=checkpointer,
)

# %%
from langchain.messages import HumanMessage

# 设定thread_id，作为会话标识
config = {"configurable": {"thread_id": "thread_2"}}

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='b88520d7-56ba-438c-b93c-089dbc8a41fa'), AIMessage(content='虎哥你好！🐯 很高兴认识你～猫猫真的超可爱，软乎乎的爪爪、毛茸茸的肚子，还有那种“全世界都是朕的”傲娇气质，谁能不爱呢！😻 你家里有养猫吗？还是正在云吸猫呀？需要什么猫猫表情包、冷知识或者饲养建议，随时喊我！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 15, 'total_tokens': 93, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'e0c1647f-44f4-42f5-b57a-0656675549bc', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2184-4949-79e0-884d-25969047a255-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 78, 'total_tokens': 93, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢的动物是什么？")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='b88520d7-56ba-438c-b93c-089dbc8a41fa'), AIMessage(content='虎哥你好！🐯 很高兴认识你～猫猫真的超可爱，软乎乎的爪爪、毛茸茸的肚子，还有那种“全世界都是朕的”傲娇气质，谁能不爱呢！😻 你家里有养猫吗？还是正在云吸猫呀？需要什么猫猫表情包、冷知识或者饲养建议，随时喊我！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 15, 'total_tokens': 93, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'e0c1647f-44f4-42f5-b57a-0656675549bc', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2184-4949-79e0-884d-25969047a255-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 78, 'total_tokens': 93, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我最喜欢的动物是什么？', additional_kwargs={}, response_metadata={}, id='37c85e99-bdb2-4637-8d60-e4a7ce5a657a'), AIMessage(content='虎哥，你刚才自己说的呀——**猫猫**！🐱  \n（但如果你偷偷喜欢别的动物…我猜是**老虎**？毕竟你叫虎哥，说不定和老虎一样爱打盹儿又霸气？😼）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 102, 'total_tokens': 155, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 102}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'c4e9f110-871a-486d-9327-5e46f35cbd92', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2184-7630-79b0-a01c-97a84f8c26d5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 102, 'output_tokens': 53, 'total_tokens': 155, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 4.记忆管理
#
# 当会话历史过长时，可能会超出模型的上下文窗口限制，常见的解决方案有：
# - 修剪消息
# - 删除消息
# - 总结消息摘要
#
# 这里我们演示总结消息摘要的方案

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.runnables import RunnableConfig

# 初始化checkpointer
checkpointer = InMemorySaver()
# 初始化中间件
middleware = SummarizationMiddleware(
    model="deepseek-chat",
    trigger=("messages", 3), #  触发时机，当消息数超过3时，进行总结
    keep=("messages", 1) #  保留的会话数，超过2条
)
# 创建agent
agent = create_agent(
    model="deepseek-chat",
    middleware=[middleware],
    checkpointer=checkpointer,
)

config: RunnableConfig = {"configurable": {"thread_id": "thread_4"}}
# 制造长会话历史
agent.invoke({"messages": [HumanMessage(content="你好，我是虎哥.")]}, config)
agent.invoke({"messages": [HumanMessage(content="我最喜欢的运动是乒乓")]}, config)
agent.invoke({"messages": [HumanMessage(content="我最喜欢的动物是猫猫")]}, config)
# 测试效果
final_response = agent.invoke({"messages": HumanMessage(content="你还记得我吗？")}, config)

# %%
print(final_response)
# Out:
# {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\n用户（虎哥）尚未提出明确任务请求，处于兴趣探索阶段。已表达对乒乓球和猫猫的兴趣，整体目标有待后续明确。\n\n## SUMMARY\n- 用户自称“虎哥”，喜欢打乒乓球（最爱的运动）和猫猫（最爱的动物）。\n- AI已确认这两项兴趣，并提供了乒乓球细分方向（快攻、弧圈、防守反击）及参与场景，以及猫猫品种话题。\n- 用户尚未选择具体方向或提出具体问题，会话停留在闲聊和兴趣分享层面。\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\n等待虎哥指定具体需求或问题（如乒乓球技术建议、装备推荐、赛事讨论、猫猫相关话题等），以便进一步提供针对性帮助。', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='fecc7757-d04c-4b3d-b26e-4e1490021b30'), HumanMessage(content='你还记得我吗？', additional_kwargs={}, response_metadata={}, id='da4429f9-c771-4b49-8eae-6f293de274af'), AIMessage(content='哈哈，当然记得！虎哥你好呀！  \n你是那位爱打乒乓球、又喜欢猫猫的虎哥嘛！之前聊过你最爱乒乓球（快攻、弧圈、防守反击都提到了），也提过你喜欢猫猫，品种啥的还没细聊。  \n\n今天是想聊聊球技、装备，还是晒猫？或者有新想法啦？我在这儿等着呢～ 😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 180, 'total_tokens': 263, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 180}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '352285bb-55fb-499f-b77f-e92be2ca4df1', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2197-1200-76d1-a92c-fbb9d0f6afd4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 180, 'output_tokens': 83, 'total_tokens': 263, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
for message in final_response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# 用户（虎哥）尚未提出明确任务请求，处于兴趣探索阶段。已表达对乒乓球和猫猫的兴趣，整体目标有待后续明确。
#
# ## SUMMARY
# - 用户自称“虎哥”，喜欢打乒乓球（最爱的运动）和猫猫（最爱的动物）。
# - AI已确认这两项兴趣，并提供了乒乓球细分方向（快攻、弧圈、防守反击）及参与场景，以及猫猫品种话题。
# - 用户尚未选择具体方向或提出具体问题，会话停留在闲聊和兴趣分享层面。
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# 等待虎哥指定具体需求或问题（如乒乓球技术建议、装备推荐、赛事讨论、猫猫相关话题等），以便进一步提供针对性帮助。
# ================================ Human Message =================================
#
# 你还记得我吗？
# ================================== Ai Message ==================================
#
# 哈哈，当然记得！虎哥你好呀！
# 你是那位爱打乒乓球、又喜欢猫猫的虎哥嘛！之前聊过你最爱乒乓球（快攻、弧圈、防守反击都提到了），也提过你喜欢猫猫，品种啥的还没细聊。
#
# 今天是想聊聊球技、装备，还是晒猫？或者有新想法啦？我在这儿等着呢～ 😄
